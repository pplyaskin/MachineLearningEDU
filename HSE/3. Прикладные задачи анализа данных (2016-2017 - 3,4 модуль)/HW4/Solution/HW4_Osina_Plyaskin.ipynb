# %%
import pandas as pd

# %% [markdown]
# ## Обработка файла для SPMF

# %%
data = pd.read_csv('task1-2/phrase-company.txt', sep=' ',header=None, names=['phrase', 'company', 'count'])

# %%
data['phrase'] = data['phrase'].apply(str)

# %%
data.head(3)
# Out:
#   phrase  company  count
# 0      0       23      1
# 1      0       96      1
# 2      0      188      1

# %%
data = data.groupby('company')['phrase'].apply(lambda x: ' '.join(x))

# %%
data.head(3)
# Out:
# company
# 0    332 345 355 663 665 674 681 691 696 719 730 96...
# 1    281 285 286 287 740 741 766 767 830 831 832 83...
# 2    22 33 129 218 249 250 251 287 646 654 655 657 ...
# Name: phrase, dtype: object

# %%
data.to_csv('task1-2/input.txt', index=None)

# %%
data.shape
# Out:
# (2000,)

# %%
print('minsup =',35/2000)
# Out:
# minsup = 0.0175

# %% [markdown]
# ## Полученные результаты

# %%
phrases = pd.read_csv('task1-2\phrases.txt', header = None, names=['phrase']) #фразы
phrares_list = phrases.values.flatten()

# %%
print (' "{0}" "{1}" ==> "{2}"'.format(phrares_list[663], phrares_list[674], phrares_list[345]))
print (' "{0}" "{1}" ==> "{2}"'.format(phrares_list[345], phrares_list[674], phrares_list[663]))
print (' "{0}" ==> "{1}"'.format(phrares_list[2536], phrares_list[2336]))
print (' "{0}" ==> "{1}"'.format(phrares_list[355], phrares_list[345]))
print (' "{0}" ==> "{1}"'.format(phrares_list[355], phrares_list[674]))
print (' "{0}" ==> "{1}"'.format(phrares_list[2159], phrares_list[2166]))
# Out:
#  "business home" "business home opportunity" ==> "based business home"
#  "based business home" "business home opportunity" ==> "business home"
#  "marketing online" ==> "internet marketing"
#  "based business home opportunity" ==> "based business home"
#  "based business home opportunity" ==> "business home opportunity"
#  "hosting site web" ==> "hosting web"

# %% [markdown]
# ## 3.

# %%
a1 = pd.read_csv('task1-2/1a.txt', sep='#SUP:', names=['phrases', 'SUP'])
a1['count_phrases'] = a1['phrases'].apply(lambda x: len(x.split()))
a1 = a1[a1['count_phrases'] == a1.count_phrases.max()]
a1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':
#                                             phrases  SUP  count_phrases
# 3313    989 998 1001 1011 1016 1019 1021 1888 1906    35              9
# 3321     989 995 998 1001 1011 1016 1019 1021 1906    36              9
# 3512    989 995 1001 1011 1016 1019 1021 1888 1906    37              9
# 3681     989 995 998 1001 1011 1016 1021 1888 1906    36              9
# 5403   120 1074 1075 1170 1233 1471 2156 2159 2166    35              9
# 17062     969 989 995 998 1011 1021 1882 1888 1906    36              9
# 17236     969 989 995 998 1001 1011 1021 1888 1906    35              9
# ...

# %%
for p in a1.loc[3681]['phrases'].split():
    print (''.join(phrares_list[int(p)]))
# Out:
# casino gambling
# casino gambling online
# casino game
# casino game online
# casino internet
# casino line
# casino online
# gambling internet
# gambling online

# %%
b1 = pd.read_csv('task1-2/1b.txt', sep='#SUP:', names=['phrases', 'SUP']);
b1['count_phrases'] = b1['phrases'].apply(lambda x: len(x.split()))
b1 = b1[b1['count_phrases'] == 8]
b1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':
#                                         phrases  SUP  count_phrases
# 2084    1021 1906 1011 989 1001 1019 1006 1016    35              8
# 2088     1021 1906 995 989 1001 1019 1006 1016    35              8
# 2103     1021 1906 995 1011 989 1001 1006 1016    35              8
# 2120      995 1888 1011 989 1001 998 1019 1016    35              8
# 2125     1021 1906 1011 989 1001 998 1019 1016    37              8
# 2130      1021 1906 995 989 1001 998 1019 1016    37              8
# 2136     1021 1906 995 1011 1001 998 1019 1016    37              8
# 2150    1021 1906 1888 1011 989 1001 1019 1016    38              8
# ...

# %%
for p in b1.loc[2286]['phrases'].split():
    print (''.join(phrares_list[int(p)]))
# Out:
# casino online
# gambling online
# casino gambling online
# casino
# casino internet
# casino game online
# casino game
# casino line

# %%
c1 = pd.read_csv('task1-2/1c.txt', sep='#SUP:', names=['phrases', 'SUP']);
c1['count_phrases'] = c1['phrases'].apply(lambda x: len(x.split()))
c1 = c1[c1['count_phrases'] == 7]
c1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':
#                                   phrases  SUP  count_phrases
# 868      1021 1906 995 1011 989 998 1883    35              7
# 871    1021 1906 1888 1011 989 1001 1883    35              7
# 872     1021 1906 995 1011 989 1001 1883    36              7
# 878     1021 1906 969 1888 1011 989 1883    35              7
# 879    1021 1906 1882 1888 1011 989 1883    35              7
# 880     1021 1906 995 1888 1011 989 1883    37              7
# 882      1021 1906 995 969 1011 989 1883    35              7
# 1012     1021 1906 995 989 1001 998 1040    35              7
# 1013    1021 1906 995 1011 1001 998 1040    35              7
# ...

# %%
for p in c1.loc[3632]['phrases'].split():
    print (''.join(phrares_list[int(p)]))
# Out:
# hosting web
# hosting site web
# hosting services web
# affordable hosting web
# business hosting web
# cost hosting low web
# hosting page web
